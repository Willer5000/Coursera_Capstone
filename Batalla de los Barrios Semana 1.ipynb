# %% [markdown]
# <head>
# 	<style>
# 		.center {
# 			text-align: center;
# 		}
# 	</style>
# 	<b><h1 class="center">Batalla de los Vecindarios (Semana 1)</h1></b>
# 	<b><h2 class="center">Análisis de la diversidad culinaria en la industria de restaurantes en Buenos Aires: una perspectiva geográfica</h2></b>
# </head>

# %% [markdown]
# <div style="text-align:center">
#   <img src="https://cdn.guialowcost.es/wp-content/uploads/restaurante-el-cuartito.jpg" alt="portada">
# </div>

# %% [markdown]
# # INTRODUCCION
# La ciudad de Buenos Aires es conocida por su rica cultura culinaria y por ser una ciudad que ofrece una gran variedad de opciones gastronómicas. Sin embargo, ¿cómo está distribuida esta diversidad culinaria en la ciudad? ¿Existen zonas con una alta concentración de restaurantes que ofrecen una determinada cocina? ¿Cuál es la variedad de opciones gastronómicas disponibles en cada barrio y comuna?
#
# En esta investigación se busca responder estas preguntas utilizando datos de registros de restaurantes en Buenos Aires. Se utilizarán técnicas de análisis exploratorio de datos y visualización geoespacial para comprender la distribución geográfica de los restaurantes en la ciudad y la diversidad culinaria que ofrecen. Además, se aplicarán técnicas de agrupamiento para identificar patrones en la distribución geográfica de los restaurantes y analizar la diversidad culinaria de la ciudad.
#
# El objetivo de este estudio es proporcionar una perspectiva geográfica de la diversidad culinaria en la industria de restaurantes en Buenos Aires y ayudar a los consumidores a identificar zonas con una alta concentración de restaurantes que ofrecen su tipo de cocina preferida. Además, los resultados de este estudio pueden ser de interés para los propietarios de restaurantes y emprendedores que buscan abrir nuevos negocios en la ciudad.

# %% [markdown]
# ## 1. Antecedentes
# La ciudad de Buenos Aires cuenta con una amplia variedad de restaurantes que ofrecen diferentes tipos de cocina, lo que ha llevado a una creciente competencia en la industria de la restauración. A pesar de la diversidad culinaria en la ciudad, algunos barrios y comunas han sido identificados como concentraciones de ciertos tipos de cocina, lo que puede limitar las opciones de los clientes y afectar la competitividad de los restaurantes.
#
# En este contexto, surge la necesidad de analizar la diversidad culinaria en la industria de los restaurantes en Buenos Aires, desde una perspectiva geográfica. Este análisis permitiría determinar si hay una falta de diversidad culinaria en ciertas zonas de la ciudad y si esto se relaciona con el éxito de los restaurantes en esas áreas.
#
# Además, la pandemia de COVID-19 ha tenido un impacto significativo en la industria de los restaurantes en todo el mundo, y Buenos Aires no ha sido una excepción. Es importante tener en cuenta el impacto de la pandemia en la industria de la restauración al realizar este análisis.

# %% [markdown]
# ### 1.1 Problema de Investigación
#
# La ciudad de Buenos Aires es conocida por su diversidad cultural y gastronómica, lo que se refleja en su amplia oferta de restaurantes. Sin embargo, algunos estudios han sugerido que ciertas zonas de la ciudad pueden estar dominadas por ciertos tipos de cocina, limitando la variedad de opciones disponibles para los clientes.
#
# Este problema puede tener varias consecuencias negativas, como la disminución de la competitividad de los restaurantes en esas áreas, la falta de oportunidades para la introducción de nuevas cocinas y la falta de diversidad en la dieta de los residentes y turistas de la ciudad. Además, la concentración de restaurantes de un mismo tipo de cocina puede ser indicativa de la falta de planificación urbana en la ciudad y de la necesidad de políticas públicas que fomenten la diversidad culinaria.
#
# Por lo tanto, el objetivo de esta investigación es analizar la diversidad culinaria en la industria de restaurantes en Buenos Aires, desde una perspectiva geográfica. Se busca determinar si existen zonas de la ciudad que tienen una concentración excesiva de un tipo de cocina en particular y cómo esto puede afectar la competencia entre restaurantes en esas áreas. Se espera que los resultados de esta investigación proporcionen información valiosa para los propietarios de restaurantes, los responsables de la planificación urbana y los consumidores de la ciudad.

# %% [markdown]
# ### 1.2 Problema comercial: Identificación de oportunidades de inversión en la industria de restaurantes de Buenos Aires
# Esta investigación tiene como objetivo ayudar a los inversores interesados en el mercado de restaurantes de Buenos Aires a identificar oportunidades comerciales mediante el análisis de la diversidad culinaria y la distribución geográfica de los restaurantes en la ciudad.
#
# Los resultados de esta investigación serán beneficiosos tanto para inversores locales como internacionales que buscan maximizar su rentabilidad en la industria de restaurantes. Al tener una comprensión clara de la distribución geográfica y diversidad culinaria de los restaurantes en Buenos Aires, los inversores podrán tomar decisiones más informadas y estratégicas sobre dónde invertir su capital y qué tipo de restaurantes tienen el potencial de tener éxito en la ciudad.

# %% [markdown]
# ## 2. Descripción de los datos
# Los datos que se utilizarán para esta investigación son un conjunto de registros de restaurantes ubicados en Buenos Aires, Argentina. Estos datos incluyen información como la longitud y la latitud del restaurante, su nombre, categoría, tipo de cocina, comuna y barrio en el que se encuentra ubicado.
#
# Los datos están almacenados en un archivo GeoJson y se pueden leer fácilmente en Python utilizando la biblioteca Pandas. Además, se utilizarán datos obtenidos a través de la API de Foursquare y similares.
#
# ### 2.1 Utilización de los datos para resolver el problema
# Para resolver el problema de investigación, se pueden utilizar técnicas de análisis exploratorio de datos (EDA), visualización geoespacial de los datos y la información obtenida a través de la API de Foursquare y similares.
#
# En primer lugar, se puede realizar un análisis exploratorio básico para comprender la estructura y distribución de los datos. Se pueden calcular estadísticas descriptivas como la media, la mediana y la desviación estándar de la longitud y la latitud de los restaurantes para determinar la distribución geográfica de los mismos.
#
# A continuación, se pueden utilizar técnicas de visualización geoespacial para representar la ubicación de los restaurantes en un mapa de la ciudad de Buenos Aires y los datos obtenidos a través de la API de Foursquare y similares. Esto permitiría identificar posibles zonas de la ciudad con una alta concentración de un tipo de cocina en particular y los lugares de mayor interés para los turistas.
#
# Finalmente, se puede realizar un análisis más profundo utilizando técnicas de agrupamiento (clustering) para identificar patrones en la distribución geográfica de los restaurantes y los lugares de mayor interés para los turistas. Se pueden utilizar algoritmos como K-means para agrupar los restaurantes y lugares de interés en función de su ubicación y tipo de cocina. Esto permitiría identificar zonas de la ciudad con una alta densidad de restaurantes que ofrecen una determinada cocina y analizar la diversidad culinaria de la ciudad, así como determinar los lugares de mayor interés para los turistas.
#
# En resumen, los datos de los registros de restaurantes en Buenos Aires, junto con los datos obtenidos a través de la API de Foursquare y similares, se utilizarán para realizar un análisis exploratorio de datos y visualización geoespacial para comprender la distribución geográfica y diversidad culinaria de la industria de restaurantes en la ciudad, así como para determinar los lugares de mayor interés para los turistas. Se utilizarán técnicas de agrupamiento para identificar patrones en la distribución geográfica de los restaurantes y lugares de interés y analizar la diversidad culinaria de la ciudad. Todo esto permitirá responder la pregunta de investigación planteada en este estudio.

# %% [markdown]
# ## 3. Prodecimiento

# %% [markdown]
# 1. Se utiliza la biblioteca Geopandas para leer un archivo GeoJSON que contiene información geoespacial de la ciudad de Buenos Aires. Los datos se acceden como un dataframe de Pandas y se imprimen los primeros 5 registros para verificar la carga correcta del archivo.

# %%
import geopandas as gpd

# Lee el archivo GeoJSON
df = gpd.read_file(r'G:\Mi unidad\Coursera\Ciencia de Datos Aplicada caso Capstone (Proyecto Final)\Proyecto final\CapitalFederal.GeoJson')

# Accede a los datos como un dataframe de pandas
df_data = df

# Imprime los primeros 5 registros del dataframe
print(df_data.head())
# Out:
#         long        lat    id           nombre    categoria       cocina  \
# 0 -58.363307 -34.622963  1602     GUANTANAMERA  RESTAURANTE       CUBANA
# 1 -58.392330 -34.621554   676  1843 VINACOTECA      VINERIA         None
# 2 -58.453542 -34.560311   487     2080 EXPRESS  RESTAURANTE  TRADICIONAL
# 3 -58.475491 -34.677051  2737               22         CAFE      MINUTAS
# 4 -58.425437 -34.585695     2         4 EN 2 I  RESTAURANTE         None
#
#       ambientacion   telefono  mail                    horario  \
# 0          MODERNO  4314 0770  None                       None
# 1             None  4779 0806  None  lunes a domingo de 8 a 00
# 2  CLASICO PORTEÑO  4788 4500  None  lunes a domingo de 8 a 00
# 3          MODERNO       None  None                       None
# 4             None  4832 9510  None                       None
#
#              calle_nombre  calle_altura calle_cruce  \
# 0  MOREAU DE JUSTO ALICIA          2092        None
# ...

# %% [markdown]
# 2. Luego, selecciona solo las columnas relevantes para la investigación y las almacena en un nuevo DataFrame de pandas para su posterior análisis. Finalmente, se imprimen los primeros cinco registros del DataFrame para verificar que los datos se cargaron correctamente.

# %%
# Cargar el archivo GeoJSON como un GeoDataFrame
df = gpd.read_file(r'G:\Mi unidad\Coursera\Ciencia de Datos Aplicada caso Capstone (Proyecto Final)\Proyecto final\CapitalFederal.GeoJson')

# Seleccionar las columnas de interés
df_data = df[['long', 'lat', 'nombre', 'categoria', 'cocina', 'comuna', 'barrio']]

# Imprime los primeros 5 registros del dataframe
print(df_data.head())
# Out:
#         long        lat           nombre    categoria       cocina     comuna  \
# 0 -58.363307 -34.622963     GUANTANAMERA  RESTAURANTE       CUBANA   Comuna 1
# 1 -58.392330 -34.621554  1843 VINACOTECA      VINERIA         None   Comuna 3
# 2 -58.453542 -34.560311     2080 EXPRESS  RESTAURANTE  TRADICIONAL  Comuna 13
# 3 -58.475491 -34.677051               22         CAFE      MINUTAS   Comuna 8
# 4 -58.425437 -34.585695         4 EN 2 I  RESTAURANTE         None  Comuna 14
#
#           barrio
# 0  Puerto Madero
# 1  San Cristobal
# 2       Belgrano
# 3   Villa Lugano
# 4        Palermo

# %% [markdown]
# 3. Se crea el dataframe df_CFBA separa eliminar todas las filas que contienen valores nulos (dropna()) del DataFrame original df_data. Luego, la función head() se utiliza para imprimir las primeras cinco filas del nuevo DataFrame df_CFBA.

# %%
df_CFBA = df_data.dropna()
df_CFBA = df_CFBA.reindex(columns=['nombre', 'categoria', 'cocina', 'comuna', 'barrio', 'lat', 'long'])
df_CFBA
# Out:
#                 nombre    categoria         cocina     comuna         barrio  \
# 0         GUANTANAMERA  RESTAURANTE         CUBANA   Comuna 1  Puerto Madero
# 2         2080 EXPRESS  RESTAURANTE    TRADICIONAL  Comuna 13       Belgrano
# 3                   22         CAFE        MINUTAS   Comuna 8   Villa Lugano
# 5           4 X 4 CAFE          BAR        MINUTAS  Comuna 14        Palermo
# 6          5TA AVENIDA  RESTAURANTE        MINUTAS   Comuna 1    San Nicolas
# ...                ...          ...            ...        ...            ...
# 2818  ZOE PIZZA & CAFE  RESTAURANTE       PORTEÃ‘A   Comuna 3      Balvanera
# 2819             ZOMBI  RESTAURANTE        MINUTAS   Comuna 1    San Nicolas
# 2820              ZONA  RESTAURANTE  INTERNACIONAL  Comuna 13       NuÃƒÂ±ez
# 2821           ZOO BAR  RESTAURANTE        MINUTAS   Comuna 3      Balvanera
# 2822          Angelito          BAR        MINUTAS  Comuna 15   Villa Crespo
#
#             lat       long
# ...

# %% [markdown]
# Se corrigen valores a codigos manejables con undecode

# %%
from unidecode import unidecode

df_CFBA["nombre"] = df_CFBA["nombre"].apply(lambda x: unidecode(x))
df_CFBA["cocina"] = df_CFBA["cocina"].apply(lambda x: unidecode(x))
df_CFBA["barrio"] = df_CFBA["barrio"].apply(lambda x: unidecode(x))

df_CFBA
# Out:
#                 nombre    categoria         cocina     comuna         barrio  \
# 0         GUANTANAMERA  RESTAURANTE         CUBANA   Comuna 1  Puerto Madero
# 2         2080 EXPRESS  RESTAURANTE    TRADICIONAL  Comuna 13       Belgrano
# 3                   22         CAFE        MINUTAS   Comuna 8   Villa Lugano
# 5           4 X 4 CAFE          BAR        MINUTAS  Comuna 14        Palermo
# 6          5TA AVENIDA  RESTAURANTE        MINUTAS   Comuna 1    San Nicolas
# ...                ...          ...            ...        ...            ...
# 2818  ZOE PIZZA & CAFE  RESTAURANTE       PORTEA'A   Comuna 3      Balvanera
# 2819             ZOMBI  RESTAURANTE        MINUTAS   Comuna 1    San Nicolas
# 2820              ZONA  RESTAURANTE  INTERNACIONAL  Comuna 13      NuAfA+-ez
# 2821           ZOO BAR  RESTAURANTE        MINUTAS   Comuna 3      Balvanera
# 2822          Angelito          BAR        MINUTAS  Comuna 15   Villa Crespo
#
#             lat       long
# ...

# %% [markdown]
# Se eliminan ubicaciones atipicas

# %%
# Crear una nueva columna para indicar si las coordenadas están dentro de los límites
df_CFBA["dentro_limites"] = (df_CFBA["lat"] >= -34.705) & (df_CFBA["lat"] <= -34.515) & \
                            (df_CFBA["long"] >= -58.530) & (df_CFBA["long"] <= -58.335)

# Filtrar el DataFrame para mantener solo las filas dentro de los límites
df_CFBA = df_CFBA[df_CFBA["dentro_limites"]]

# Eliminar la columna creada
df_CFBA.drop("dentro_limites", axis=1, inplace=True)

# %%
df_CFBA
# Out:
#                 nombre    categoria         cocina     comuna         barrio  \
# 0         GUANTANAMERA  RESTAURANTE         CUBANA   Comuna 1  Puerto Madero
# 2         2080 EXPRESS  RESTAURANTE    TRADICIONAL  Comuna 13       Belgrano
# 3                   22         CAFE        MINUTAS   Comuna 8   Villa Lugano
# 5           4 X 4 CAFE          BAR        MINUTAS  Comuna 14        Palermo
# 6          5TA AVENIDA  RESTAURANTE        MINUTAS   Comuna 1    San Nicolas
# ...                ...          ...            ...        ...            ...
# 2818  ZOE PIZZA & CAFE  RESTAURANTE       PORTEA'A   Comuna 3      Balvanera
# 2819             ZOMBI  RESTAURANTE        MINUTAS   Comuna 1    San Nicolas
# 2820              ZONA  RESTAURANTE  INTERNACIONAL  Comuna 13      NuAfA+-ez
# 2821           ZOO BAR  RESTAURANTE        MINUTAS   Comuna 3      Balvanera
# 2822          Angelito          BAR        MINUTAS  Comuna 15   Villa Crespo
#
#             lat       long
# ...

# %% [markdown]
# Se crea el mapa para visualizar la calidad de los datos (se utiliza el metodo ipyleaflet debido a que folium tarda mucho en cargar el mapa)

# %%
from ipyleaflet import Map, CircleMarker

# Crear mapa centrado en Buenos Aires
mapa = Map(center=(-34.603722, -58.381592), zoom=12)

# Agregar un círculo para cada restaurante en el dataframe
for index, row in df_CFBA.iterrows():
    circle = CircleMarker(location=(row['lat'], row['long']), radius=2, color="blue", fill_color="blue")
    mapa.add_layer(circle)

# Mostrar el mapa
mapa
# Out:
# Map(center=[-34.603722, -58.381592], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title…

# %% [markdown]
# <div style="text-align:center">
#   <img src="https://live.staticflickr.com/65535/52751582212_cbf9a05447_z.jpg" alt="dataframe_CFBA">
# </div>

# %% [markdown]
# 4. Foursqare
# El siguiente código utiliza la API de Foursquare para buscar restaurantes en Buenos Aires que estén abiertos en el momento de hacer la búsqueda. Se especifican las coordenadas geográficas del centro de la ciudad y se utiliza el parámetro "sort" para ordenar los resultados por distancia. Luego se hace una solicitud HTTP GET a la URL de la API de Foursquare con los parámetros y cabeceras necesarios. La respuesta se convierte en un objeto JSON y se almacena en la variable "data".

# %%
import pandas as pd
import requests

url = "https://api.foursquare.com/v3/places/search"

params = {
  	"query": "restaurant",
  	"ll": "-34.603722,-58.381592",
  	"open_now": "true",
  	"sort":"DISTANCE"
}

headers = {
    "Accept": "application/json",
    "Authorization": "fsq3pz4x+pH00OKi1LqAAw2+HLEmHnzJgVb53Qkpow+sZKc="
}

response = requests.request("GET", url, params=params, headers=headers)

data = response.json()
data
# Out:
# {'results': [{'fsq_id': '4b05871af964a520028022e3',
#    'categories': [{'id': 13070,
#      'name': 'Argentinian Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/argentinian_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 193,
#    'geocodes': {'main': {'latitude': -34.602384, 'longitude': -58.380101},
#     'roof': {'latitude': -34.602384, 'longitude': -58.380101}},
#    'link': '/v3/places/4b05871af964a520028022e3',
#    'location': {'address': 'Lavalle 941',
#     'country': 'AR',
#     'cross_street': 'e/ Carlos Pellegrini y Suipacha',
#     'formatted_address': 'Lavalle 941 (e/ Carlos Pellegrini y Suipacha), 1047 Buenos Aires, Buenos Aires F.C.',
#     'locality': 'Buenos Aires',
#     'postcode': '1047',
#     'region': 'Buenos Aires F.C.'},
#    'name': 'La Estancia',
#    'related_places': {},
#    'timezone': 'America/Argentina/Buenos_Aires'},
#   {'fsq_id': '4b05871bf964a5202c8022e3',
#    'categories': [{'id': 13064,
# ...

# %% [markdown]
# El siguiente código convierte los resultados en un DataFrame de Pandas que contiene información sobre los restaurantes que cumplen con los criterios de búsqueda especificados.

# %%
# Verificar que la clave 'results' existe en los datos devueltos
if 'results' in data:
    # Si existe, convertir los resultados en un dataframe
    results = data['results']
    restaurants = []
    for r in results:
        name = r.get('name', None)
        latitude = r['geocodes']['main'].get('latitude', None)
        longitude = r['geocodes']['main'].get('longitude', None)
        restaurants.append([name, latitude, longitude])
    df_CFBA2 = pd.DataFrame(restaurants, columns=['name', 'latitude', 'longitude'])
else:
    # Si no existe, imprimir mensaje de error
    print("No se encontraron resultados para la búsqueda especificada.")

# %%
df_CFBA2
# Out:
#                name   latitude  longitude
# 0       La Estancia -34.602384 -58.380101
# 1     Las Cuartetas -34.603674 -58.378627
# 2  El Café de Marco -34.606239 -58.384313
# 3  Pizzeria Guerrin -34.604109 -58.385976
# 4    Los Inmortales -34.602410 -58.377245
# 5       Delhi Mahal -34.598997 -58.383182
# 6  The New Brighton -34.604522 -58.375877
# 7        Broccolino -34.599294 -58.378376
# 8      Café Tortoni -34.608739 -58.378190
# 9   Santos Manjares -34.597866 -58.380259

# %% [markdown]
# Se crea un mapa de Foursquare para ver la calidad de los resultados

# %%
import folium

# Coordenadas del centro del mapa
map_center2 = [-34.603722, -58.381592]

# Crea el mapa
m2 = folium.Map(location=map_center2, zoom_start=12)

# Agrega un marcador para cada restaurante en el DataFrame df_CFBA
for index, row in df_CFBA2.iterrows():
    folium.Marker([row['latitude'], row['longitude']], popup=row['name']).add_to(m2)

# Muestra el mapa
m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS = false; L_NO_TOUCH = false; L_DISABLE_3D = false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <div style="text-align:center">
#   <img src="https://live.staticflickr.com/65535/52752640968_567e9df9ca.jpg" alt="df_CFBA2">
# </div>

# %% [markdown]
# ### Conclusión SEMANA 1
# Después de realizar una búsqueda de lugares utilizando la API de Foursquare, se obtuvo un DataFrame denominado df_CFBA2, que contiene información de los 10 restaurantes más cercanos a las coordenadas -34.603722,-58.381592 (que representan la ubicación de Buenos Aires, Argentina).
#
# Sin embargo, para una mayor cantidad de datos y una representación más completa de los lugares de Buenos Aires, utilizaremos el archivo "CapitalFederal.geojson" descargado de la página de datos abiertos del Gobierno de la Ciudad de Buenos Aires (https://data.buenosaires.gob.ar/dataset/), el cual contiene información de diferentes categorías de lugares.
#
# Este archivo nos permitirá crear un DataFrame llamado df_CFBA con información más detallada y amplia de los lugares en Buenos Aires, lo que nos permitirá realizar un análisis más completo.

# %% [markdown]
# Por lo tanto se crea el csv del df_CFBA para trabajar en la semana 2 de la Batalla de los Barrios:

# %%
df_CFBA.to_csv('Coordinates_of_Gastronomy_in_Buenos_Aires.csv', index=False)
